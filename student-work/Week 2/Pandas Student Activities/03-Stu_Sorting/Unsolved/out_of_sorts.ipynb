# %% [markdown]
# ### Import Libraries and Dependencies

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read CSV as Pandas DataFrame

# %%
# Read in csv
csv_path = Path("../Resources/tsla_google_finance.csv")
tsla_df = pd.read_csv(csv_path)
tsla_df.head()
# Out:
#        Date   Close
# 0  11/13/18  338.73
# 1  11/14/18  344.00
# 2  11/15/18  348.44
# 3  11/16/18  354.31
# 4  11/19/18  353.47

# %% [markdown]
# ### Index Data by `Date`

# %%
# Set `Date` as index
tsla_date_index_df = tsla_df.set_index("Date")
tsla_date_index_df.head()
# Out:
#            Close
# Date
# 11/13/18  338.73
# 11/14/18  344.00
# 11/15/18  348.44
# 11/16/18  354.31
# 11/19/18  353.47

# %% [markdown]
# ### Assess and Clean Data

# %%
# Check for nulls
tsla_date_index_df.isnull().sum()

# Drop missing values
tsla_df = tsla_date_index_df.dropna()

# Validate no more missing values
tsla_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %% [markdown]
# ### Calculate Daily Returns

# %%
# Calculate daily returns
daily_return_average = tsla_df["Close"].mean()
print(round(daily_return_average, 2))
# Out:
# 301.67

# %% [markdown]
# ### Sort the DataFrame by `Close` to Get Records with Top Daily Returns

# %%
# Sort data by `Close` in descending order
tsla_df = tsla_df.sort_values(by="Close", ascending=False)
tsla_df
# Out:
#            Close
# Date
# 12/13/18  376.79
# 12/11/18  366.76
# 12/12/18  366.60
# 12/14/18  365.71
# 12/10/18  365.15
# ...          ...
# 4/30/19   238.69
# 4/26/19   235.14
# 5/1/19    234.01
# 5/14/19   232.31
# 5/13/19   227.01
#
# [124 rows x 1 columns]

# %% [markdown]
# ### Slice Out 5 Records

# %%
# Slice out top 5
tsla_top5_df = tsla_df.head()
tsla_top5_df
# Out:
#            Close
# Date
# 12/13/18  376.79
# 12/11/18  366.76
# 12/12/18  366.60
# 12/14/18  365.71
# 12/10/18  365.15

# %% [markdown]
# ### Plot Top 5 Performing Days for TSLA Daily Returns

# %%
# Plot top 5 performing days
plt.plot(tsla_top5_df);

# %%
# Alternatively, visualizing the returns as a bar chart:
plt.bar(tsla_top5_df.index, tsla_top5_df["Close"]);
